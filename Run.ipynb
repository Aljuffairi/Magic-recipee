# %%
import mr.py
# Out:
# Shared setup loaded.
# CSV file: recipes.csv
# Welcome to the Recipe Manager!
# Loaded 18 recipe(s).
#
# === Recipe Manager ===
# 1. Add a new recipe
# 2. Search for recipes by ingredient
# 3. View all recipes
# 4. Get a random recipe
# 5. Generate a shopping list
# 6. Filter by category
# 7. Suggest a recipe (cooking history)
# 0. Exit
# Enter your choice:  2
# Enter the ingredient to search for:  water
# Search results for: water
# Boiled Egg : (Category: Breakfast)
# Instant Noodles : (Category: Lunch)
# Rice with Fried Egg : (Category: Dinner)
#
# === Recipe Manager ===
# 1. Add a new recipe
# 2. Search for recipes by ingredient
# 3. View all recipes
# 4. Get a random recipe
# 5. Generate a shopping list
# 6. Filter by category
# 7. Suggest a recipe (cooking history)
# 0. Exit
# Enter your choice:  5
# --- All Recipes ---
#
# 1. Boiled Egg
#    Preperation Time : 9 minutes
#    Difficulty level : Easy
#    Rating    : -
#
# 2. Grilled Cheese
#    Preperation Time : 4 minutes
# ...
